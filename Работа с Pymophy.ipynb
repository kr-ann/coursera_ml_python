# %%
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

# %%
import codecs
f = codecs.open(r'C:\Users\Admin.Ann-s\Desktop\test.txt', encoding = 'koi8-r')
#text = f.read().decode('utf-8')
f.close()

# %%
text
# Out:
# u'\ufeff\u041f\u0440\u043e \u043c\u0435\u0442\u0440\u0438\u043a\u0438. \u0412\u043e-\u043f\u0435\u0440\u0432\u044b\u0445, \u043c\u0435\u0442\u0440\u0438\u043a\u0438, \u043a\u043e\u0442\u043e\u0440\u044b\u0435 \u044f \u043f\u0440\u0438\u0441\u043b\u0430\u043b\u0430 \u0432 \u043f\u0440\u043e\u0448\u043b\u044b\u0439 \u0440\u0430\u0437 - \u044d\u0442\u043e \u0442\u043e\u043b\u044c\u043a\u043e "lexical", \u0430 \u0441\u0443\u0449\u0435\u0441\u0442\u0432\u0443\u044e\u0442 \u0442\u0430\u043a\u0436\u0435 "style", "structure", "wikipedia" measures \u0438 \u043d\u0435\u043a\u043e\u0442\u043e\u0440\u044b\u0435 \u0434\u0440\u0443\u0433\u0438\u0435 - \u0442\u043e \u0435\u0441\u0442\u044c \u0438\u0445 \u0434\u0435\u0439\u0441\u0442\u0432\u0438\u0442\u0435\u043b\u044c\u043d\u043e \u043c\u043d\u043e\u0433\u043e.\r\n\u0414\u043b\u044f \u0438\u0441\u043f\u043e\u043b\u044c\u0437\u043e\u0432\u0430\u043d\u0438\u044f \u0432\u0441\u0435\u0445 \u0438\u0437 \u043d\u0438\u0445 \u043d\u0435\u043e\u0431\u0445\u
# ...

# %%
import re
result = re.sub('[\W+]',' ',text)
splitted = result.lower().split(' ')

# %%
i = 0
for word in splitted:
    if (word == '') or (word == '\t') or (word == '\n') or (word=='\r') or (word == '\r\n'):
        del splitted[i]
    i+=1

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
i=0
lemmatized = []
for word in splitted:
    lemmatized.append(morph.parse(word)[0].normal_form)

# %%
f= open(r'C:\Users\Admin.Ann-s\Desktop\test_result.txt', 'w')
f.write(' '.join(lemmatized))
f.close()
